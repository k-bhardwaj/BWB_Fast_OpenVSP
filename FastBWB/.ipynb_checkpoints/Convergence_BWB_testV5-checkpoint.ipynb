# %% [markdown]
# <div class="row">
#   <div class="column">
#     <img src="./img/logo-ISAE_SUPAERO.png" width="200">
#   </div>
# </div>

# %% [markdown]
# # BWB CONVERGENCE V5
# #### Note on errors: Wet area negative, performance altitude out of bound
# 17 March 2023

# %% [markdown]
# ## 1. Import libraries

# %%
import openmdao.api as om
from fastoad.module_management.constants import ModelDomain
from fastoad.module_management.service_registry import RegisterOpenMDAOSystem, RegisterSubmodel
import logging
import shutil
import fastoad.api as oad
import os.path as pth
import os
import yaml
from ruamel.yaml import YAML
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Directory set up

# %%
# # Print the current working directory
directory = "{0}".format(os.getcwd())
print('Directory: ', directory)

# Assign data and work folder paths: 
DATA_FOLDER_PATH = directory +'\data'
WORK_FOLDER_PATH = directory +'\workspace'

# Print data and work folder paths: 
print('- Data folder path is: ',DATA_FOLDER_PATH)
print('- Work folder path is: ',WORK_FOLDER_PATH)
# Out:
# Directory:  C:\Users\Sandra\Documents\5. SUPAERO\4. MAE\4. RP\HWP5\4. FAST-OAD\BWB_convergence\Test convergence-v5
# - Data folder path is:  C:\Users\Sandra\Documents\5. SUPAERO\4. MAE\4. RP\HWP5\4. FAST-OAD\BWB_convergence\Test convergence-v5\data
# - Work folder path is:  C:\Users\Sandra\Documents\5. SUPAERO\4. MAE\4. RP\HWP5\4. FAST-OAD\BWB_convergence\Test convergence-v5\workspace

# %% [markdown]
# ## 3. Initialization

# %%
# For having log messages on screen
# logging.basicConfig(level=logging.INFO, format="%(levelname)-8s: %(message)s")

##################################################################################


# BWB CONFIFURATION: 
CONFIGURATION_FILE_BWB = pth.join(WORK_FOLDER_PATH, "master_configurationold.yml")
SOURCE_FILE_BWB = pth.join(DATA_FOLDER_PATH, "master_inputs_mission_test.xml")
# oad.generate_configuration_file(CONFIGURATION_FILE_tubeWing, overwrite=True)


##################################################################################

# TUBE AND WING CONFIGURATION

# To run the simulation:
# CONFIGURATION_FILE_tubeWing = pth.join(WORK_FOLDER_PATH, "oad_process_tubeWing.yml")
# SOURCE_FILE_tubeWing = pth.join(DATA_FOLDER_PATH, "CeRAS01_baseline.xml")
# oad.generate_configuration_file(CONFIGURATION_FILE_tubeWing, overwrite=True)

# To upload the inputs and outputs directly: 
inputs_tubeWing = pth.join(WORK_FOLDER_PATH, "problem_inputs_tubeWing_saved.xml")
outputs_tubeWing = pth.join(WORK_FOLDER_PATH, "problem_outputs_tubeWing_saved.xml")

# %% [markdown]
# ## 4. Generate inputs

# %%
yaml = YAML()
yaml.preserve_quotes = True

##################################################################################


# BWB CONFIFURATION:
with open(CONFIGURATION_FILE_BWB) as f:
    test = yaml.load(f)
test['input_file'] = './problem_inputs_BWB.xml' 
test['output_file'] = './problem_outputs_BWB.xml' 
with open(CONFIGURATION_FILE_BWB, 'wb') as f:
    yaml.dump(test, f)
inputsBWB = oad.generate_inputs(CONFIGURATION_FILE_BWB, SOURCE_FILE_BWB, overwrite=True)

oad.variable_viewer(inputsBWB)

##################################################################################

# TUBE AND WING CONFIGURATION
# with open(CONFIGURATION_FILE_tubeWing) as f:
#     test = yaml.load(f)
# test['input_file'] = './problem_inputs_tubeWing.xml' 
# test['output_file'] = './problem_outputs_tubeWing.xml' 
# with open(CONFIGURATION_FILE_tubeWing, 'wb') as f:
#     yaml.dump(test, f)
# oad.generate_inputs(CONFIGURATION_FILE_tubeWing, SOURCE_FILE_tubeWing, overwrite=True)
# Out:
# C:\Users\Sandra\anaconda3\lib\site-packages\openmdao\utils\options_dictionary.py:354: OMDeprecationWarning:'payload_from_npax.BWBtest' is not a valid python name and will become an invalid option name in a future release. You can prevent this warning (and future exceptions) by declaring this option using a valid python name.
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %% [markdown]
# ## 5. Evaluate problem

# %%
# BWB CONFIFURATION:
BWB_problem = oad.evaluate_problem(CONFIGURATION_FILE_BWB, overwrite=True)

##################################################################################

# TUBE AND WING CONFIGURATION
# tubeWing_problem = oad.evaluate_problem(CONFIGURATION_FILE_tubeWing, overwrite=True)
# Out:
# C:\Users\Sandra\anaconda3\lib\site-packages\openmdao\utils\options_dictionary.py:354: OMDeprecationWarning:'payload_from_npax.BWBtest' is not a valid python name and will become an invalid option name in a future release. You can prevent this warning (and future exceptions) by declaring this option using a valid python name.
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# This is the new wing area in file compute_wing_area_bwb: [161.48513562]
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# Span value in bwb_compute_y_wing.py: 24.798682596385493
# Loaded wing area on bwb_compute_wet_area_wing.py: [161.48513562]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.43902923]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [62.25134379]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [124.50268758]
#
#
# This is the new wing area in file compute_wing_area_bwb: [129.87207953]
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
#
#
# Span value in bwb_compute_y_wing.py: 22.23925481651546
# Loaded wing area on bwb_compute_wet_area_wing.py: [129.87207953]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [12.67029125]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [36.31464894]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [72.62929788]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\openmdao\core\system.py:2275, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2274 try:
# -> 2275     yield
#    2276 except Exception:
#
# File ~\anaconda3\lib\site-packages\openmdao\core\explicitcomponent.py:285, in ExplicitComponent._compute_wrapper(self)
#     284 else:
# --> 285     self.compute(*args)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\openmdao\mission.py:390, in MissionComponent.compute(self, inputs, outputs, discrete_inputs, discrete_outputs)
#     389 _LOGGER.info(message_prefix + "Using mission definition.")
# --> 390 self._compute_mission(inputs, outputs)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\openmdao\mission.py:474, in MissionComponent._compute_mission(self, inputs, outputs)
#     466 end_of_takeoff = FlightPoint(
#     467     time=0.0,
#     468     mass=inputs[self._mission_vars.TOW],
#    (...)
#     471     ground_distance=0.0,
#     472 )
# --> 474 self.flight_points = self._mission_wrapper.compute(inputs, outputs, end_of_takeoff)
#     476 # Final ================================================================
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\openmdao\mission_wrapper.py:112, in MissionWrapper.compute(self, inputs, outputs, start_flight_point)
#     110         outputs[name_root + ":distance"] = end.ground_distance - start.ground_distance
# --> 112 flight_points = mission.compute_from(start_flight_point)
#     113 flight_points.loc[0, "name"] = flight_points.loc[1, "name"]
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\base.py:54, in FlightSequence.compute_from(self, start)
#      53 for part in self.flight_sequence:
# ---> 54     flight_points = part.compute_from(part_start)
#      55     if len(parts) > 0 and len(flight_points) > 1:
#      56         # First point of the segment is omitted, as it is the last of previous segment.
#      57         #
#      58         # But sometimes (especially in the case of simplistic segments), the new first
#      59         # point may contain more information than the previous last one. In such case,
#      60         # it is interesting to complete the previous last one.
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\routes.py:122, in RangedRoute.compute_from(self, start)
#     121 if 0.0 in climb_descent_distances:
# --> 122     return self._solve_cruise_distance(start)
#     124 self.cruise_distance = self.flight_distance - np.sum(climb_descent_distances)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\routes.py:144, in RangedRoute._solve_cruise_distance(self, start)
#     139 """
#     140 Adjusts cruise distance through a solver to have whole route that
#     141 matches provided flight distance.
#     142 """
# --> 144 root_scalar(
#     145     self._compute_flight,
#     146     args=(start,),
#     147     x0=self.flight_distance * 0.5,
#     148     x1=self.flight_distance * 0.25,
#     149     xtol=0.5e3,
#     150     method="secant",
#     151 )
#     153 return self._flight_points
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_root_scalar.py:257, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     256         kwargs['tol'] = kwargs.pop('xtol')
# --> 257     r, sol = methodc(f, x0, args=args, fprime=None, fprime2=None,
#     258                      x1=x1, **kwargs)
#     259 elif meth in ['newton']:
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\zeros.py:326, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     325     p1 += (eps if p1 >= 0 else -eps)
# --> 326 q0 = func(p0, *args)
#     327 funcalls += 1
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\routes.py:164, in RangedRoute._compute_flight(self, cruise_distance, start)
#     163 self.cruise_distance = cruise_distance
# --> 164 self._flight_points = super().compute_from(start)
#     165 obtained_distance = (
#     166     self._flight_points.iloc[-1].ground_distance
#     167     - self._flight_points.iloc[0].ground_distance
#     168 )
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\base.py:54, in FlightSequence.compute_from(self, start)
#      53 for part in self.flight_sequence:
# ---> 54     flight_points = part.compute_from(part_start)
#      55     if len(parts) > 0 and len(flight_points) > 1:
#      56         # First point of the segment is omitted, as it is the last of previous segment.
#      57         #
#      58         # But sometimes (especially in the case of simplistic segments), the new first
#      59         # point may contain more information than the previous last one. In such case,
#      60         # it is interesting to complete the previous last one.
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\base.py:54, in FlightSequence.compute_from(self, start)
#      53 for part in self.flight_sequence:
# ---> 54     flight_points = part.compute_from(part_start)
#      55     if len(parts) > 0 and len(flight_points) > 1:
#      56         # First point of the segment is omitted, as it is the last of previous segment.
#      57         #
#      58         # But sometimes (especially in the case of simplistic segments), the new first
#      59         # point may contain more information than the previous last one. In such case,
#      60         # it is interesting to complete the previous last one.
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\altitude_change.py:109, in AltitudeChangeSegment.compute_from(self, start)
#     107     start.true_airspeed = atm.true_airspeed
# --> 109 return super().compute_from(start)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:172, in FlightSegment.compute_from(self, start)
#     171 while np.abs(previous_point_to_target) > tol:
# --> 172     self._add_new_flight_point(flight_points, self.time_step)
#     173     last_point_to_target = self.get_distance_to_target(flight_points)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:250, in FlightSegment._add_new_flight_point(self, flight_points, time_step)
#     249 new_point = self.compute_next_flight_point(flight_points, time_step)
# --> 250 self.complete_flight_point(new_point)
#     251 flight_points.append(new_point)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:311, in FlightSegment.complete_flight_point(self, flight_point)
#     309 flight_point.drag = flight_point.CD * reference_force
# --> 311 self.compute_propulsion(flight_point)
#     312 flight_point.slope_angle, flight_point.acceleration = self.get_gamma_and_acceleration(
#     313     flight_point
#     314 )
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:428, in ManualThrustSegment.compute_propulsion(self, flight_point)
#     427 flight_point.thrust_is_regulated = False
# --> 428 self.propulsion.compute_flight_points(flight_point)
#
# File ~\anaconda3\lib\site-packages\fastoad\model_base\propulsion.py:220, in FuelEngineSet.compute_flight_points(self, flight_points)
#     218     flight_points.thrust = flight_points.thrust / self.engine_count
# --> 220 self.engine.compute_flight_points(flight_points)
#     221 flight_points.thrust = flight_points.thrust * self.engine_count
#
# File ~\anaconda3\lib\site-packages\fastoad_cs25\models\propulsion\fuel_propulsion\rubber_engine\rubber_engine.py:133, in RubberEngine.compute_flight_points(self, flight_points)
#     129 k_sfc_alt = interp1d(
#     130     [-1000.0, 0.0, 13106.4, 20000.0],
#     131     np.hstack((self.k_sfc_sl, self.k_sfc_sl, self.k_sfc_cr, self.k_sfc_cr)),
#     132 )
# --> 133 k_sfc = k_sfc_alt(flight_points.altitude)
#     135 flight_points.sfc = sfc * k_sfc
#
# File ~\anaconda3\lib\site-packages\scipy\interpolate\polyint.py:78, in _Interpolator1D.__call__(self, x)
#      77 x, x_shape = self._prepare_x(x)
# ---> 78 y = self._evaluate(x)
#      79 return self._finish_y(y, x_shape)
#
# File ~\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:684, in interp1d._evaluate(self, x_new)
#     683 if not self._extrapolate:
# --> 684     below_bounds, above_bounds = self._check_bounds(x_new)
#     685     if len(y_new) > 0:
#     686         # Note fill_value must be broadcast up to the proper size
#     687         # and flattened to work here
#
# File ~\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:716, in interp1d._check_bounds(self, x_new)
#     715 if self.bounds_error and above_bounds.any():
# --> 716     raise ValueError("A value in x_new is above the interpolation "
#     717                      "range.")
#     719 # !! Should we emit a warning if some values are out of bounds?
#     720 # !! matlab does not.
#
# ValueError: A value in x_new is above the interpolation range.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # BWB CONFIFURATION:
# ----> 2 BWB_problem = oad.evaluate_problem(CONFIGURATION_FILE_BWB, overwrite=True)
#
# File ~\anaconda3\lib\site-packages\fastoad\cmd\api.py:626, in evaluate_problem(configuration_file_path, overwrite)
#     617 def evaluate_problem(configuration_file_path: str, overwrite: bool = False) -> FASTOADProblem:
#     618     """
#     619     Runs model according to provided problem file
#     620
#    (...)
#     624     :raise FastPathExistsError: if overwrite==False and output data file of problem already exists
#     625     """
# --> 626     return _run_problem(configuration_file_path, overwrite, "run_model")
#
# File ~\anaconda3\lib\site-packages\fastoad\cmd\api.py:599, in _run_problem(configuration_file_path, overwrite, mode, auto_scaling)
#     597 start_time = time()
#     598 if mode == "run_model":
# --> 599     problem.run_model()
#     600     problem.optim_failed = False  # Actually, we don't know
#     601 else:
#
# File ~\anaconda3\lib\site-packages\fastoad\openmdao\problem.py:75, in FASTOADProblem.run_model(self, case_prefix, reset_iter_counts)
#      74 def run_model(self, case_prefix=None, reset_iter_counts=True):
# ---> 75     status = super().run_model(case_prefix, reset_iter_counts)
#      76     ValidityDomainChecker.check_problem_variables(self)
#      77     BundleLoader().clean_memory()
#
# File ~\anaconda3\lib\site-packages\openmdao\core\problem.py:811, in Problem.run_model(self, case_prefix, reset_iter_counts)
#     808     record_model_options(self, self._run_counter)
#     810     self.model._clear_iprint()
# --> 811     self.model.run_solve_nonlinear()
#     812 finally:
#     813     self._recording_iter.prefix = old_prefix
#
# File ~\anaconda3\lib\site-packages\openmdao\core\system.py:3994, in System.run_solve_nonlinear(self)
#    3988 """
#    3989 Compute outputs.
#    3990
#    3991 This calls _solve_nonlinear, but with the model assumed to be in an unscaled state.
#    3992 """
#    3993 with self._scaled_context_all():
# -> 3994     self._solve_nonlinear()
#
# File ~\anaconda3\lib\site-packages\openmdao\core\group.py:2560, in Group._solve_nonlinear(self)
#    2557 name = self.pathname if self.pathname else 'root'
#    2559 with Recording(name + '._solve_nonlinear', self.iter_count, self):
# -> 2560     self._nonlinear_solver._solve_with_cache_check()
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\solver.py:825, in NonlinearSolver._solve_with_cache_check(self)
#     823         raise
#     824 else:
# --> 825     self.solve()
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\solver.py:583, in NonlinearSolver.solve(self)
#     581 if self.options['debug_print']:
#     582     self._print_exc_debug_info()
# --> 583 raise err
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\solver.py:579, in NonlinearSolver.solve(self)
#     575 """
#     576 Run the solver.
#     577 """
#     578 try:
# --> 579     self._solve()
#     580 except Exception as err:
#     581     if self.options['debug_print']:
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\solver.py:656, in NonlinearSolver._solve(self)
#     654     self.linesearch.options['print_bound_enforce'] = False
#     655 else:
# --> 656     self._single_iteration()
#     658 self._iter_count += 1
#     659 self._run_apply()
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\nonlinear\nonlinear_block_gs.py:142, in NonlinearBlockGS._single_iteration(self)
#     139         outputs_n = outputs.asarray(copy=True)
#     141 self._solver_info.append_subsolver()
# --> 142 self._gs_iter()
#     143 self._solver_info.pop()
#     145 if use_aitken:
#     146     # compute the change in the outputs after the NLBGS iteration
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\solver.py:787, in NonlinearSolver._gs_iter(self)
#     785 if subsys._is_local:
#     786     try:
# --> 787         subsys._solve_nonlinear()
#     788     except AnalysisError as err:
#     789         if 'reraise_child_analysiserror' not in self.options or \
#     790                 self.options['reraise_child_analysiserror']:
#
# File ~\anaconda3\lib\site-packages\openmdao\core\group.py:2560, in Group._solve_nonlinear(self)
#    2557 name = self.pathname if self.pathname else 'root'
#    2559 with Recording(name + '._solve_nonlinear', self.iter_count, self):
# -> 2560     self._nonlinear_solver._solve_with_cache_check()
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\nonlinear\nonlinear_runonce.py:26, in NonlinearRunOnce._solve_with_cache_check(self)
#      25 def _solve_with_cache_check(self):
# ---> 26     self.solve()
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\nonlinear\nonlinear_runonce.py:45, in NonlinearRunOnce.solve(self)
#      41             subsys._solve_nonlinear()
#      43 # If this is not a parallel group, transfer for each subsystem just prior to running it.
#      44 else:
# ---> 45     self._gs_iter()
#      47 rec.abs = 0.0
#      48 rec.rel = 0.0
#
# File ~\anaconda3\lib\site-packages\openmdao\solvers\solver.py:787, in NonlinearSolver._gs_iter(self)
#     785 if subsys._is_local:
#     786     try:
# --> 787         subsys._solve_nonlinear()
#     788     except AnalysisError as err:
#     789         if 'reraise_child_analysiserror' not in self.options or \
#     790                 self.options['reraise_child_analysiserror']:
#
# File ~\anaconda3\lib\site-packages\openmdao\core\explicitcomponent.py:311, in ExplicitComponent._solve_nonlinear(self)
#     309 with self._unscaled_context(outputs=[self._outputs], residuals=[self._residuals]):
#     310     self._residuals.set_val(0.0)
# --> 311     self._compute_wrapper()
#
# File ~\anaconda3\lib\site-packages\openmdao\core\explicitcomponent.py:285, in ExplicitComponent._compute_wrapper(self)
#     283                 self._discrete_outputs[name] = val
#     284 else:
# --> 285     self.compute(*args)
#
# File ~\anaconda3\lib\contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     135     value = typ()
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#     142     return exc is not value
#
# File ~\anaconda3\lib\site-packages\openmdao\core\system.py:2281, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2279         raise
#    2280     else:
# -> 2281         raise err_type(
#    2282             f"{self.msginfo}: Error calling {fname}(), {err}").with_traceback(trace)
#    2283 finally:
#    2284     self._inputs.read_only = False
#
# File ~\anaconda3\lib\site-packages\openmdao\core\system.py:2275, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2272 self._residuals.read_only = protect_residuals
#    2274 try:
# -> 2275     yield
#    2276 except Exception:
#    2277     err_type, err, trace = sys.exc_info()
#
# File ~\anaconda3\lib\site-packages\openmdao\core\explicitcomponent.py:285, in ExplicitComponent._compute_wrapper(self)
#     283                 self._discrete_outputs[name] = val
#     284 else:
# --> 285     self.compute(*args)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\openmdao\mission.py:390, in MissionComponent.compute(self, inputs, outputs, discrete_inputs, discrete_outputs)
#     388 else:
#     389     _LOGGER.info(message_prefix + "Using mission definition.")
# --> 390     self._compute_mission(inputs, outputs)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\openmdao\mission.py:474, in MissionComponent._compute_mission(self, inputs, outputs)
#     465 self._compute_taxi_out(inputs, outputs, propulsion_model)
#     466 end_of_takeoff = FlightPoint(
#     467     time=0.0,
#     468     mass=inputs[self._mission_vars.TOW],
#    (...)
#     471     ground_distance=0.0,
#     472 )
# --> 474 self.flight_points = self._mission_wrapper.compute(inputs, outputs, end_of_takeoff)
#     476 # Final ================================================================
#     477 end_of_mission = FlightPoint.create(self.flight_points.iloc[-1])
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\openmdao\mission_wrapper.py:112, in MissionWrapper.compute(self, inputs, outputs, start_flight_point)
#     109     if name_root + ":distance" in outputs:
#     110         outputs[name_root + ":distance"] = end.ground_distance - start.ground_distance
# --> 112 flight_points = mission.compute_from(start_flight_point)
#     113 flight_points.loc[0, "name"] = flight_points.loc[1, "name"]
#     115 nb_levels = np.max([len(n.split(":")) for n in flight_points["name"]])
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\base.py:54, in FlightSequence.compute_from(self, start)
#      52 part_start = start
#      53 for part in self.flight_sequence:
# ---> 54     flight_points = part.compute_from(part_start)
#      55     if len(parts) > 0 and len(flight_points) > 1:
#      56         # First point of the segment is omitted, as it is the last of previous segment.
#      57         #
#      58         # But sometimes (especially in the case of simplistic segments), the new first
#      59         # point may contain more information than the previous last one. In such case,
#      60         # it is interesting to complete the previous last one.
#      61         last_flight_points = parts[-1]
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\routes.py:122, in RangedRoute.compute_from(self, start)
#     119     climb_descent_distances.extend(self._get_ground_distances(phase))
#     121 if 0.0 in climb_descent_distances:
# --> 122     return self._solve_cruise_distance(start)
#     124 self.cruise_distance = self.flight_distance - np.sum(climb_descent_distances)
#     125 return super().compute_from(start)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\routes.py:144, in RangedRoute._solve_cruise_distance(self, start)
#     138 def _solve_cruise_distance(self, start: FlightPoint) -> pd.DataFrame:
#     139     """
#     140     Adjusts cruise distance through a solver to have whole route that
#     141     matches provided flight distance.
#     142     """
# --> 144     root_scalar(
#     145         self._compute_flight,
#     146         args=(start,),
#     147         x0=self.flight_distance * 0.5,
#     148         x1=self.flight_distance * 0.25,
#     149         xtol=0.5e3,
#     150         method="secant",
#     151     )
#     153     return self._flight_points
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_root_scalar.py:257, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     255     if 'xtol' in kwargs:
#     256         kwargs['tol'] = kwargs.pop('xtol')
# --> 257     r, sol = methodc(f, x0, args=args, fprime=None, fprime2=None,
#     258                      x1=x1, **kwargs)
#     259 elif meth in ['newton']:
#     260     if x0 is None:
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\zeros.py:326, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     324     p1 = x0 * (1 + eps)
#     325     p1 += (eps if p1 >= 0 else -eps)
# --> 326 q0 = func(p0, *args)
#     327 funcalls += 1
#     328 q1 = func(p1, *args)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\routes.py:164, in RangedRoute._compute_flight(self, cruise_distance, start)
#     156 """
#     157 Computes flight for provided cruise distance
#     158
#    (...)
#     161 :return: difference between computes distance and self.flight_distance
#     162 """
#     163 self.cruise_distance = cruise_distance
# --> 164 self._flight_points = super().compute_from(start)
#     165 obtained_distance = (
#     166     self._flight_points.iloc[-1].ground_distance
#     167     - self._flight_points.iloc[0].ground_distance
#     168 )
#     169 return self.flight_distance - obtained_distance
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\base.py:54, in FlightSequence.compute_from(self, start)
#      52 part_start = start
#      53 for part in self.flight_sequence:
# ---> 54     flight_points = part.compute_from(part_start)
#      55     if len(parts) > 0 and len(flight_points) > 1:
#      56         # First point of the segment is omitted, as it is the last of previous segment.
#      57         #
#      58         # But sometimes (especially in the case of simplistic segments), the new first
#      59         # point may contain more information than the previous last one. In such case,
#      60         # it is interesting to complete the previous last one.
#      61         last_flight_points = parts[-1]
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\base.py:54, in FlightSequence.compute_from(self, start)
#      52 part_start = start
#      53 for part in self.flight_sequence:
# ---> 54     flight_points = part.compute_from(part_start)
#      55     if len(parts) > 0 and len(flight_points) > 1:
#      56         # First point of the segment is omitted, as it is the last of previous segment.
#      57         #
#      58         # But sometimes (especially in the case of simplistic segments), the new first
#      59         # point may contain more information than the previous last one. In such case,
#      60         # it is interesting to complete the previous last one.
#      61         last_flight_points = parts[-1]
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\altitude_change.py:109, in AltitudeChangeSegment.compute_from(self, start)
#     106     atm.mach = start.mach
#     107     start.true_airspeed = atm.true_airspeed
# --> 109 return super().compute_from(start)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:172, in FlightSegment.compute_from(self, start)
#     170 tol = 1.0e-5  # Such accuracy is not needed, but ensures reproducibility of results.
#     171 while np.abs(previous_point_to_target) > tol:
# --> 172     self._add_new_flight_point(flight_points, self.time_step)
#     173     last_point_to_target = self.get_distance_to_target(flight_points)
#     175     if last_point_to_target * previous_point_to_target < 0.0:
#     176
#     177         # Target has been exceeded. Let's look for the exact time step using root_scalar.
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:250, in FlightSegment._add_new_flight_point(self, flight_points, time_step)
#     243 """
#     244 Appends a new flight point to provided flight point list.
#     245
#     246 :param flight_points: list of previous flight points, modified in place.
#     247 :param time_step: time step for new computed flight point.
#     248 """
#     249 new_point = self.compute_next_flight_point(flight_points, time_step)
# --> 250 self.complete_flight_point(new_point)
#     251 flight_points.append(new_point)
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:311, in FlightSegment.complete_flight_point(self, flight_point)
#     308     flight_point.CL = flight_point.CD = 0.0
#     309 flight_point.drag = flight_point.CD * reference_force
# --> 311 self.compute_propulsion(flight_point)
#     312 flight_point.slope_angle, flight_point.acceleration = self.get_gamma_and_acceleration(
#     313     flight_point
#     314 )
#
# File ~\anaconda3\lib\site-packages\fastoad\models\performances\mission\segments\base.py:428, in ManualThrustSegment.compute_propulsion(self, flight_point)
#     426 flight_point.thrust_rate = self.thrust_rate
#     427 flight_point.thrust_is_regulated = False
# --> 428 self.propulsion.compute_flight_points(flight_point)
#
# File ~\anaconda3\lib\site-packages\fastoad\model_base\propulsion.py:220, in FuelEngineSet.compute_flight_points(self, flight_points)
#     217 if flight_points.thrust is not None:
#     218     flight_points.thrust = flight_points.thrust / self.engine_count
# --> 220 self.engine.compute_flight_points(flight_points)
#     221 flight_points.thrust = flight_points.thrust * self.engine_count
#
# File ~\anaconda3\lib\site-packages\fastoad_cs25\models\propulsion\fuel_propulsion\rubber_engine\rubber_engine.py:133, in RubberEngine.compute_flight_points(self, flight_points)
#     128 # SFC correction for NEO engines dependent on altitude.
#     129 k_sfc_alt = interp1d(
#     130     [-1000.0, 0.0, 13106.4, 20000.0],
#     131     np.hstack((self.k_sfc_sl, self.k_sfc_sl, self.k_sfc_cr, self.k_sfc_cr)),
#     132 )
# --> 133 k_sfc = k_sfc_alt(flight_points.altitude)
#     135 flight_points.sfc = sfc * k_sfc
#     136 flight_points.thrust_rate = thrust_rate
#
# File ~\anaconda3\lib\site-packages\scipy\interpolate\polyint.py:78, in _Interpolator1D.__call__(self, x)
#      57 """
#      58 Evaluate the interpolant
#      59
#    (...)
#      75
#      76 """
#      77 x, x_shape = self._prepare_x(x)
# ---> 78 y = self._evaluate(x)
#      79 return self._finish_y(y, x_shape)
#
# File ~\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:684, in interp1d._evaluate(self, x_new)
#     682 y_new = self._call(self, x_new)
#     683 if not self._extrapolate:
# --> 684     below_bounds, above_bounds = self._check_bounds(x_new)
#     685     if len(y_new) > 0:
#     686         # Note fill_value must be broadcast up to the proper size
#     687         # and flattened to work here
#     688         y_new[below_bounds] = self._fill_value_below
#
# File ~\anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:716, in interp1d._check_bounds(self, x_new)
#     713     raise ValueError("A value in x_new is below the interpolation "
#     714                      "range.")
#     715 if self.bounds_error and above_bounds.any():
# --> 716     raise ValueError("A value in x_new is above the interpolation "
#     717                      "range.")
#     719 # !! Should we emit a warning if some values are out of bounds?
#     720 # !! matlab does not.
#     721 return below_bounds, above_bounds
#
# ValueError: 'performance.mission_computation' <class MissionComponent>: Error calling compute(), A value in x_new is above the interpolation range.

# %% [markdown]
# ## 6. Variable viewer

# %%
# BWB CONFIFURATION:
print('-------------------------------------------------------------')
print('BWB CONFIGURATION')
oad.variable_viewer(BWB_problem.output_file_path)
print('-------------------------------------------------------------')


##################################################################################
# TUBE AND WING CONFIGURATION
# print('-------------------------------------------------------------')
# print('Tube and Wing Configuration CONFIGURATION')
# oad.variable_viewer(tubeWing_problem.output_file_path)
# print('-------------------------------------------------------------')


# To upload directly the output file: 
print('-------------------------------------------------------------')
print('TUBE AND WING CONFIGURATION')
# oad.variable_viewer(pth.join(WORK_FOLDER_PATH, "problem_outputs_tubeWing.xml"))
oad.variable_viewer(outputs_tubeWing)
print('-------------------------------------------------------------')

# %% [markdown]
# ## 7. Visualization
# ### 7.1 Geometry visualization

# %%
# ALESSANDRO'S CODE: 
print('-------------------------------------------------------------')
print('BWB + TUBE AND WING PLOT')
print('-------------------------------------------------------------')


# BWB DATA
output_dataBWB = oad.DataFile(pth.join(WORK_FOLDER_PATH, "problem_outputs_BWB.xml"))
y2_wingBWB = output_dataBWB["data:geometry:wing:root:y"].value[0]
y4_wingBWB = output_dataBWB["data:geometry:wing:tip:y"].value[0]
y3_wingBWB = output_dataBWB["data:geometry:wing:kink:y"].value[0]
x4_wingBWB = output_dataBWB["data:geometry:wing:tip:leading_edge:x:local"].value[0]
l4_wingBWB = output_dataBWB["data:geometry:wing:tip:chord"].value[0]
l2_wingBWB = output_dataBWB["data:geometry:wing:root:chord"].value[0]

xBWB = [0, y2_wingBWB, y4_wingBWB, y4_wingBWB, y3_wingBWB, y2_wingBWB, 0, 0]
yBWB = [0, 0, x4_wingBWB, (x4_wingBWB + l4_wingBWB), l2_wingBWB, l2_wingBWB, l2_wingBWB, 0]

# TUBE AND WING DATA
# output_dataTW = oad.DataFile(pth.join(WORK_FOLDER_PATH, "problem_outputs_tubeWing_saved.xml"))
output_dataTW = oad.DataFile(outputs_tubeWing)
y2_wingTW = output_dataTW["data:geometry:wing:root:y"].value[0]
y4_wingTW = output_dataTW["data:geometry:wing:tip:y"].value[0]
y3_wingTW = output_dataTW["data:geometry:wing:kink:y"].value[0]
x4_wingTW = output_dataTW["data:geometry:wing:tip:leading_edge:x:local"].value[0]
l4_wingTW = output_dataTW["data:geometry:wing:tip:chord"].value[0]
l2_wingTW = output_dataTW["data:geometry:wing:root:chord"].value[0]

xTW = [0, y2_wingTW, y4_wingTW, y4_wingTW, y3_wingTW, y2_wingTW, 0, 0]
yTW = [0, 0, x4_wingTW, (x4_wingTW + l4_wingTW), l2_wingTW, l2_wingTW, l2_wingTW, 0]

plt.figure(1, figsize=(8, 5))
plt.plot(xBWB, yBWB,xTW, yTW)
plt.legend(["BWB", "Tube and wing"], loc=0)
plt.ylabel("Y-axis ")
plt.xlabel("X-axis ")
plt.title('Wing geometry')
plt.axis([0, 18, 0, 11])
plt.xlim([0, 20])
plt.ylim([-2.5, 12.5])


# To save figure
# plt.savefig(os.path.join(self.result_dir, 'Wing_Geometry.jpg'))
plt.show()

# %%
print('-------------------------------------------------------------')
print('BWB CONFIGURATION')
print('-------------------------------------------------------------')
# fig = oad.wing_geometry_plot(aircraft_file_path: str, name=None, fig=None, *, file_formatter=None)
# fig = oad.wing_geometry_plot(BWB_problem.output_file_path)
fig = oad.aircraft_geometry_plot(BWB_problem.output_file_path)
# fig = oad.aircraft_geometry_plot(BWB_problem.output_file_path)
# fig.show()
fig.show()

# %%
# print('-------------------------------------------------------------')
# print('BWB CONFIGURATION')
# print('-------------------------------------------------------------')
# # fig = oad.wing_geometry_plot(aircraft_file_path: str, name=None, fig=None, *, file_formatter=None)
# fig = oad.wing_geometry_plot(BWB_problem.output_file_path)
# fig.show()

# #  error - sweep0 horizontal tail!!!! 

# #################################################3

# print('-------------------------------------------------------------')
# print('TUBE AND WING CONFIGURATION')
# print('-------------------------------------------------------------')
# # fig = oad.wing_geometry_plot(aircraft_file_path: str, name=None, fig=None, *, file_formatter=None)
# fig = oad.wing_geometry_plot(tubeWing_problem.output_file_path)
# fig.show()

# print('-------------------------------------------------------------')
# print('TUBE AND WING CONFIGURATION')
# print('-------------------------------------------------------------')
# fig = oad.aircraft_geometry_plot(tubeWing_problem.output_file_path)
# fig.show()
