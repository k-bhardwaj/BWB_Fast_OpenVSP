# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Jun 15 00:09:20 2022

@author: miguel valadas
"""

from fastoad.module_management.constants import ModelDomain
from fastoad.module_management.service_registry import RegisterOpenMDAOSystem, RegisterSubmodel
import logging
import shutil
import fastoad.api as oad
import os.path as pth
import os
import yaml
from ruamel.yaml import YAML

# Import the os module
import os

# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))

# Change the current working directory
#os.chdir(r'C:\Users\Justo\FAST-OAD_notebooks\04_Testing')
os.chdir(r'C:\Users\Justo\FAST-OAD_notebooks\mini_fast')


# Print the current working directory
print("Current working directory: {0}".format(os.getcwd()))


#aux2 = r'C:\Users\migue\Documents\MV\ISAE Supaero\Research Project\FAST-OAD\mini_fast\data_mv\master_inputs.xml'
aux2 = r'C:\Users\Justo\FAST-OAD_notebooks\mini_fast\data_mv\master_inputs_mission_test.xml' #mission test
aux1 = r'C:\Users\Justo\FAST-OAD_notebooks\mini_fast\workdir_mv\master_configuration.yml'


DATA_FOLDER = 'data_mv'

WORK_FOLDER = 'workdir_mv'

CONFIGURATION_FILE_NAME = os.path.join(WORK_FOLDER, r'master_configuration.yml')
#SOURCE_FILE = os.path.join(DATA_FOLDER, r'master_inputs.xml')
SOURCE_FILE = os.path.join(DATA_FOLDER, r'master_inputs_mission_test.xml') # Mission test

CUSTOM_MODULES_FOLDER_PATH = "\models_2"
# Out:
# Current working directory: C:\Users\Justo\FAST-OAD_notebooks\mini_fast
# Current working directory: C:\Users\Justo\FAST-OAD_notebooks\mini_fast

# %%
oad.generate_inputs(aux1, aux2, overwrite=True)
os.chdir(r'C:\Users\Justo\FAST-OAD_notebooks\mini_fast')
INPUT_FILE_NAME =os.path.join(WORK_FOLDER, "problem_inputs.xml")
#oad.variable_viewer(INPUT_FILE_NAME)

# %%
aerodynamics_problem = oad.evaluate_problem(CONFIGURATION_FILE_NAME, overwrite=True)
# Out:
# Span value in bwb_compute_y_wing.py: 35.98336649923406
# Loaded wing area on bwb_compute_wet_area_wing.py: [340.]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [17.2295293]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [212.77715562]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [425.55431123]
#
#
# This is the computed wing_area 92.32482588268765
# Span value in bwb_compute_y_wing.py: 18.750876886421896
# Loaded wing area on bwb_compute_wet_area_wing.py: [92.32482588]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [11.7714036]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [5.40478171]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [10.80956343]
#
#
# This is the computed wing_area 149.1497068293292
# Span value in bwb_compute_y_wing.py: 23.832715887153128
# Loaded wing area on bwb_compute_wet_area_wing.py: [149.14970683]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.1413903]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [52.11368086]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [104.22736171]
#
#
# This is the computed wing_area 154.2932728826936
# Span value in bwb_compute_y_wing.py: 24.24017938569172
# Loaded wing area on bwb_compute_wet_area_wing.py: [154.29327288]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.26596222]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [56.33740783]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [112.67481565]
#
#
# This is the computed wing_area 155.403902226153
# Span value in bwb_compute_y_wing.py: 24.327265428302574
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.40390223]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.29277687]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.25003785]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.50007571]
#
#
# This is the computed wing_area 155.57638100656948
# Span value in bwb_compute_y_wing.py: 24.34076178655651
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.57638101]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.29693834]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.39178829]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.78357658]
#
#
# This is the computed wing_area 155.60229490185438
# Span value in bwb_compute_y_wing.py: 24.342788886313166
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.6022949]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.29756351]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.41308592]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.82617184]
#
#
# This is the computed wing_area 155.60624787010983
# Span value in bwb_compute_y_wing.py: 24.3430980901737
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.60624787]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.29765888]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.41633472]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.83266945]
#
#
# This is the computed wing_area 155.6068495824577
# Span value in bwb_compute_y_wing.py: 24.343145156177627
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.60684958]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.29767339]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.41682925]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.8336585]
#
#
# This is the computed wing_area 155.60694113900345
# Span value in bwb_compute_y_wing.py: 24.34315231773241
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.60694114]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.2976756]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.4169045]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.83380899]
#
#
# This is the computed wing_area 155.60695507235505
# Span value in bwb_compute_y_wing.py: 24.343153407599257
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.60695507]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.29767594]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.41691595]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.8338319]
#
#
# This is the computed wing_area 155.6069571927441
# Span value in bwb_compute_y_wing.py: 24.343153573456096
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.60695719]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.29767599]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.41691769]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.83383538]
#
#
# This is the computed wing_area 155.60695751542525
# Span value in bwb_compute_y_wing.py: 24.34315359869622
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.60695752]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.297676]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.41691796]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.83383591]
#
#
# This is the computed wing_area 155.60695756453103
# Span value in bwb_compute_y_wing.py: 24.34315360253727
# Loaded wing area on bwb_compute_wet_area_wing.py: [155.60695756]
# Loaded l2_wing on bwb_compute_wet_area_wing.py: [13.297676]
# Loaded y2_wing on bwb_compute_wet_area_wing.py: [3.692]
# Loaded fuselage maximum width on bwb_compute_wet_area_wing.py: [7.384]
# Loaded centerbody area on bwb_compute_wet_area_wing.py: [124.28854286]
# Resulting s_pf on bwb_compute_wet_area_wing.py  [57.416918]
# Resulting wing's wetted area on bwb_compute_wet_area_wing.py  [114.83383599]
#
#
# This is the computed wing_area 155.60695757200392
# NL: NLBGS Converged in 2 iterations

# %%
oad.variable_viewer(aerodynamics_problem.output_file_path)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…
